# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('rolling_stones_spotify.csv')
df
# Out:
#       Unnamed: 0                         name               album  \
# 0              0   Concert Intro Music - Live  Licked Live In NYC
# 1              1   Street Fighting Man - Live  Licked Live In NYC
# 2              2           Start Me Up - Live  Licked Live In NYC
# 3              3  If You Can't Rock Me - Live  Licked Live In NYC
# 4              4            Don’t Stop - Live  Licked Live In NYC
# ...          ...                          ...                 ...
# 1605        1605                        Carol  The Rolling Stones
# 1606        1606                      Tell Me  The Rolling Stones
# 1607        1607          Can I Get A Witness  The Rolling Stones
# 1608        1608   You Can Make It If You Try  The Rolling Stones
# 1609        1609              Walking The Dog  The Rolling Stones
#
#      release_date  track_number                      id  \
# 0      2022-06-10             1  2IEkywLJ4ykbhi1yRQvmsT
# 1      2022-06-10             2  6GVgVJBKkGJoRfarYRvGTU
# ...

# %%
# check for duplicated
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, album, release_date, track_number, id, uri, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, valence, popularity, duration_ms]
# Index: []

# %%
# check if there is null value
df.isnull().sum()
# Out:
# Unnamed: 0          0
# name                0
# album               0
# release_date        0
# track_number        0
# id                  0
# uri                 0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# duration_ms         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1610 non-null   int64
#  1   name              1610 non-null   object
#  2   album             1610 non-null   object
#  3   release_date      1610 non-null   object
#  4   track_number      1610 non-null   int64
#  5   id                1610 non-null   object
#  6   uri               1610 non-null   object
#  7   acousticness      1610 non-null   float64
#  8   danceability      1610 non-null   float64
#  9   energy            1610 non-null   float64
#  10  instrumentalness  1610 non-null   float64
#  11  liveness          1610 non-null   float64
#  12  loudness          1610 non-null   float64
#  13  speechiness       1610 non-null   float64
#  14  tempo             1610 non-null   float64
#  15  valence           1610 non-null   float64
# ...

# %%
df['release_date'] = pd.to_datetime(df['release_date'])  # Convert to DateTime if not already
df['year'] = df['release_date'].dt.year

# %%
df.drop(['Unnamed: 0'], axis='columns', inplace=True)

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
# based on nox plot outliers we choose the threshold
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
 
# Creating dataset
np.random.seed(10)
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(df["popularity"])
 
# show plot
plt.show()

# %%
# Visualize albums with popular songs
popularity_threshold = 50  # Adjust the popularity threshold as needed
popular_albums = df[df['popularity'] >= popularity_threshold]
popular_album_counts = popular_albums['album'].value_counts().reset_index()
popular_album_counts.columns = ['Album', 'Number of Popular Songs']
popular_album_counts = popular_album_counts.sort_values(by='Number of Popular Songs', ascending=False)
recommended_albums = popular_album_counts.head(2)

# %%
sns.barplot(x='Album',y='Number of Popular Songs', 
                 data=recommended_albums,palette=['#9e3d64','#fe5e51'] ).set_title('Most Popular Album')
# Out:
# Text(0.5, 1.0, 'Most Popular Album')

# %%
pop_df = df[['popularity', 'loudness', 'liveness', 'danceability']]
sns.set(style="ticks")
sns.pairplot(pop_df, diag_kind='kde', markers='o')
plt.suptitle("Correlation between Song Popularity and Features", y=1.02)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(x=df.year , y= df.popularity )
plt.gcf().set_size_inches(20,10) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
le = LabelEncoder()
df['album'] = le.fit_transform(df['album'])

# %%
newDf = df.drop(columns=['name','track_number','id','uri','Unnamed: 0','instrumentalness','duration_ms'],axis=1)
newDf.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 newDf = df.drop(columns=['name','track_number','id','uri','Unnamed: 0','instrumentalness','duration_ms'],axis=1)
#       2 newDf.info()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
scaler= StandardScaler()
scaled_features=scaler.fit_transform(newDf)
scaled_df=pd.DataFrame(scaled_features, columns = newDf.columns)
scaled_df

# %%
pca = PCA(n_components=2)
pca.fit(scaled_df)
X_new = pca.transform(scaled_df)
X_new.shape

# %%
wcss = []
for i in range(2, 10):
    model = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    model.fit(X_new)
    wcss.append(model.inertia_)
plt.plot(range(2, 10), wcss, 'rx-')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
labels = kmeans.fit_predict(X_new)
centroids = kmeans.cluster_centers_
cen_x = [i[0] for i in centroids]
cen_y = [i[1] for i in centroids]
# newDf['cen_x'] = labels0:cen_x[0], 1:cen_x[1], 2:cen_x[2], 3:cen_x[3], 4:cen_x[4]})
# newDf['cen_y'] = labels.map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2], 3:cen_x[3], 4:cen_x[4]})
# colors = ['#DF2020', '#81DF20', '#2095DF', '#81DF20', '#2095DF']
# newDf['c'] = newDf.cluster.map({0:colors[0], 1:colors[1], 2:colors[2], 3:colors[3], 4:colors[4]})
newDf

# %%
plt.scatter(X_new[labels == 0, 0], X_new[labels == 0, 1], s = 50, c = '#9e3d64', label = 'Cluster 1')
plt.scatter(X_new[labels == 1, 0], X_new[labels == 1, 1], s = 50, c = '#fe5e51', label = 'Cluster 2')
plt.scatter(X_new[labels == 2, 0], X_new[labels == 2, 1], s = 50, c = '#ffb554', label = 'Cluster 3')
plt.scatter(X_new[labels == 3, 0], X_new[labels == 3, 1], s = 50, c = '#f6db5f', label = 'Cluster 4')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'black', label = 'Centroids')
plt.title('Clusters of components')
plt.xlabel('components 1')
plt.ylabel('components 2')
plt.legend()
plt.show()
